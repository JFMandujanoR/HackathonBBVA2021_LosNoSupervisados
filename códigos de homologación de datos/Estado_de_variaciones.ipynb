# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import os

# %%
import pandas as pd
from fuzzywuzzy import fuzz 
from fuzzywuzzy import process
import os, glob
import time

import nltk
import numpy as np
import re
from nltk.tokenize import word_tokenize
from nltk.stem import SnowballStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
# Out:
# C:\Users\josed\anaconda3\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
def checker2(wrong_options, correct_options):
    i=0
    results = [] 
    for wrong_option in wrong_options:
#        print(wrong_option)
        
#        buenas = wrong_options[wrong_options.Nombre == wrong_option]['Nielsen'].unique()
#        print(buenas)
#        correct_options = correct_options_2[correct_options_2.Desc_Categ.isin(buenas) ]['texto_limpio']
#        print(correct_options)
        
        x = process.extract(wrong_option, correct_options, scorer=fuzz.token_sort_ratio, limit = 1)
#        print(x)
        x = pd.DataFrame(x, columns = ['CONCEPTO_BANORTE','Score2','Familia'])

        #y = process.extract(wrong_option, correct_options, scorer=fuzz.partial_ratio, limit = 6)
        #y = pd.DataFrame(y, columns = ['Similares3','Score3'])

        #x = pd.concat([x, y], axis = 1)
        x = pd.concat([x], axis = 1)

        x['CONCEPTO_BBVA'] = wrong_option
 #       x['tabla_banorte'] = tabla_banorte
 #       x['tabla_santander'] = tabla_santander
        
        results.append(x)
        i+=1
#        print(i)   
    result = pd.concat( results , sort = False)
#    result['articulo_asociado'] = tipo
    return result

# %%
def checker3(wrong_options, correct_options):
    i=0
    results = [] 
    for wrong_option in wrong_options:
#        print(wrong_option)
        
#        buenas = wrong_options[wrong_options.Nombre == wrong_option]['Nielsen'].unique()
#        print(buenas)
#        correct_options = correct_options_2[correct_options_2.Desc_Categ.isin(buenas) ]['texto_limpio']
#        print(correct_options)
        
        x = process.extract(wrong_option, correct_options, scorer=fuzz.token_sort_ratio, limit = 1)
#        print(x)
        x = pd.DataFrame(x, columns = ['CONCEPTO_SANTANDER','Score2','Familia'])

        #y = process.extract(wrong_option, correct_options, scorer=fuzz.partial_ratio, limit = 6)
        #y = pd.DataFrame(y, columns = ['Similares3','Score3'])

        #x = pd.concat([x, y], axis = 1)
        x = pd.concat([x], axis = 1)

        x['CONCEPTO_BBVA'] = wrong_option
 #       x['tabla_banorte'] = tabla_banorte
 #       x['tabla_santander'] = tabla_santander
        
        results.append(x)
        i+=1
#        print(i)   
    result = pd.concat( results , sort = False)
#    result['articulo_asociado'] = tipo
    return result

# %%
trimestres = ['1T21','2T21','2T20','3T20','4T20']

# %%
trimestre = '2T21'
reporte = 'Estado_de_variaciones'

# %%
int(trimestre[-2:])
# Out:
# 21

# %%
lista_bbva = (os.listdir('C:/Users/josed/Downloads/OUTPUT_BBVA_2021_3/Output/BBVA_'+reporte+'_'+trimestre))      
tablas_bbva = [s for s in lista_bbva if "table" in s]
bbva = pd.DataFrame()
for i in tablas_bbva:
#        print(i)
    globals()[f'bbva_'+ i[-5]] = pd.read_csv('C:/Users/josed/Downloads/OUTPUT_BBVA_2021_3/Output/BBVA_'+reporte+'_'+trimestre+'/'+i)
    globals()[f'bbva_'+ i[-5]].columns = globals()[f'bbva_'+ i[-5]].columns.str.replace(' 20','')
    globals()[f'bbva_'+ i[-5]] = globals()[f'bbva_'+ i[-5]].rename(columns = {globals()[f'bbva_'+ i[-5]].columns[0] : 'CONCEPTO'})
    bbva = pd.concat([bbva,globals()[f'bbva_'+ i[-5]]],axis = 0)


vec_c = []
for columna in bbva.columns:
    nueva_columna = str(columna)+'_BBVA'
    vec_c.append(nueva_columna)
bbva.columns = vec_c 
    
banorte = pd.DataFrame()    
lista_banorte = (os.listdir('C:/Users/josed/Downloads/OUTPUT_BBVA_2021_3/Output/Banorte_'+reporte+'_'+trimestre))      
tablas_banorte = [s for s in lista_banorte if "table" in s]
for i in tablas_banorte:
#        print(i)
    globals()[f'banorte_'+ i[-5]] = pd.read_csv('C:/Users/josed/Downloads/OUTPUT_BBVA_2021_3/Output/Banorte_'+reporte+'_'+trimestre+'/'+i)
    globals()[f'banorte_'+ i[-5]].columns = globals()[f'banorte_'+ i[-5]].columns.str.replace('1T','Mar')
    globals()[f'banorte_'+ i[-5]].columns = globals()[f'banorte_'+ i[-5]].columns.str.replace('2T','Jun')
    globals()[f'banorte_'+ i[-5]].columns = globals()[f'banorte_'+ i[-5]].columns.str.replace('3T','Sep')
    globals()[f'banorte_'+ i[-5]].columns = globals()[f'banorte_'+ i[-5]].columns.str.replace('4T','Dic')
    globals()[f'banorte_'+ i[-5]] = globals()[f'banorte_'+ i[-5]].rename(columns = {globals()[f'banorte_'+ i[-5]].columns[0] : 'CONCEPTO'})

    banorte = pd.concat([banorte,globals()[f'banorte_'+ i[-5]]],axis = 0)
   
vec_c = []
for columna in banorte.columns:
    nueva_columna = str(columna)+'_BANORTE'
    vec_c.append(nueva_columna)
banorte.columns = vec_c

santander = pd.DataFrame()   
lista_santander = (os.listdir('C:/Users/josed/Downloads/OUTPUT_BBVA_2021_3/Output/Santander_'+reporte+'_'+trimestre))      
tablas_santander = [s for s in lista_santander if "table" in s]
anio = int(trimestre[-2:])
for i in tablas_santander:
    globals()[f'santander_'+ i[-5]] = pd.read_csv('C:/Users/josed/Downloads/OUTPUT_BBVA_2021_3/Output/Santander_'+reporte+'_'+trimestre+'/'+i)
    if any("Mar" in s for s in globals()[f'santander_'+ i[-5]].columns):
        print('chido') 
    else:
        globals()[f'santander_'+ i[-5]].columns =globals()[f'santander_'+ i[-5]].values[0]
        
    vec = []
    for columna in globals()[f'santander_1'].values[0]:
        nueva_columna = str(columna)+str(anio)
        if 'Mar '+str(anio) in vec:
            nueva_columna = str(columna)+str(anio-1)
        vec.append(nueva_columna)
        
    globals()[f'santander_'+ i[-5]].columns = vec
    globals()[f'santander_'+ i[-5]].columns = globals()[f'santander_'+ i[-5]].columns.str.replace(' ','')
    globals()[f'santander_'+ i[-5]] = globals()[f'santander_'+ i[-5]].rename(columns = {globals()[f'santander_'+ i[-5]].columns[0] : 'CONCEPTO'})
    santander = pd.concat([santander,globals()[f'santander_'+ i[-5]]],axis = 0)    
    
vec_c = []
for columna in santander.columns:
    nueva_columna = str(columna)+'_SANTANDER'
    vec_c.append(nueva_columna)
santander.columns = vec_c

# %%
bbva.columns = bbva.values[0]

# %%
bbva = bbva[[bbva.columns[0],'Total Capital Contable ']][1:]

# %%
bbva.columns = ['CONCEPTO_BBVA',trimestre+'_BBVA']

# %%
bbva[bbva.columns[1]] = bbva[bbva.columns[1]].str.replace(',','')
bbva[bbva.columns[1]] = bbva[bbva.columns[1]].str.replace(' ','')
bbva[bbva.columns[1]] = bbva[bbva.columns[1]].str.replace('(','')
bbva[bbva.columns[1]] = bbva[bbva.columns[1]].str.replace(')','')
bbva[bbva.columns[1]] = bbva[bbva.columns[1]].str.replace('-','')
bbva[bbva.columns[1]] = bbva[bbva.columns[1]].str.extract('(\d+)').astype(float)
# Out:
# <ipython-input-158-e0b712532d5f>:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   bbva[bbva.columns[1]] = bbva[bbva.columns[1]].str.replace('(','')
# <ipython-input-158-e0b712532d5f>:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   bbva[bbva.columns[1]] = bbva[bbva.columns[1]].str.replace(')','')

# %%
bbva
# Out:
#                                         CONCEPTO_BBVA  2T21_BBVA
# 1                  Saldos al 31 de Diciembre de 2020    271564.0
# 2   MOVIMIENTOS INHERENTES A LAS DECISIONES DELOS ...        NaN
# 3   Traspaso del resultado neto a resultado de eje...        0.0
# 4                              Decreto de dividendos     11080.0
# 5   Capitalización de resultados de ejercicios ant...        NaN
# 6                                              Total     11080.0
# 7   MOVIMIENTOS INHERENTES AL RECONOCIMIENTO DE LA...        NaN
# 8                                     Resultado neto     25900.0
# 9   Resultado por valaluación de títulos disponibl...     6431.0
# 10  Resultado por valuación de instrumentos de cob...      466.0
# 11                   Efecto acumulado por conversión       440.0
# 12  Remediciones por beneficios definidos a los em...     3557.0
# 13                                             Total     22120.0
# 14                      Saldo al 30 de Junio de 2021    282604.0

# %%
#bbva = bbva.drop(columns = 'Unnamed: 6_BBVA')
#banorte = banorte.drop(columns = 'Unnamed: 9_BANORTE')
#santander = santander.drop(columns = 'nan19_SANTANDER')

# %%
for columna in banorte.drop(columns = ['CONCEPTO_BANORTE']).columns:
    try: 
        banorte[columna] = banorte[columna].str.replace(',','')
        banorte[columna] = banorte[columna].str.replace(' ','')
        banorte[columna] = banorte[columna].str.replace('(','')
        banorte[columna] = banorte[columna].str.replace(')','')
        banorte[columna] = banorte[columna].str.replace('-','')
        banorte[columna] = banorte[columna].str.extract('(\d+)').astype(float)
    except:
        print('...')
# Out:
# ...
# ...
# <ipython-input-161-8a17d375cf1c>:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   banorte[columna] = banorte[columna].str.replace('(','')
# <ipython-input-161-8a17d375cf1c>:6: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   banorte[columna] = banorte[columna].str.replace(')','')

# %%
banorte[trimestre+'_BANORTE'] = banorte.sum( axis = 1)
banorte = banorte[['CONCEPTO_BANORTE',trimestre+'_BANORTE']][1:]

# %%
banorte
# Out:
#                                      CONCEPTO_BANORTE  2T21_BANORTE
# 1                  Saldos al 31 de Diciembre de 2020       276570.0
# 2   Movim. inherentes a las decis. de los accionis...           0.0
# 3                           Aplicación de utilidades        40768.0
# 4   Plan de pagos basado en acciones liquidables e...         956.0
# 5                                              Total        41724.0
# 6   Movimientos inherentes al reconocimiento de la...           0.0
# 7                                 Utilidad Integral:            0.0
# 8                                     Resultado neto        24990.0
# 9   Resultado por Valuación de títulos disponibles...        2410.0
# 10  Efecto de subsidiarias, asociadas ysociedades ...           8.0
# 11                   Efecto acumulado por conversión            4.0
# 12  Resultado por Valuación de Instrumentos de cob...        3182.0
# 13  Remediciones por beneficios definidos a los em...         120.0
# 14            Intereses de obligaciónes subordinadas         3726.0
# 15                                             Total        25110.0
# 16                     Participación no controladora            2.0
# 17                     Saldos al 30 de Junio de 2021       296370.0

# %%
santander.columns = santander.values[0]

# %%
santander = santander[1:]

# %%
for columna in santander.drop(columns = ['CONCEPTO ']).columns:
    try: 
        santander[columna] = santander[columna].str.replace(',','')
        santander[columna] = santander[columna].str.replace(' ','')
        santander[columna] = santander[columna].str.replace('(','')
        santander[columna] = santander[columna].str.replace(')','')
        santander[columna] = santander[columna].str.replace('-','')
        santander[columna] = santander[columna].str.extract('(\d+)').astype(float)
    except:
        print('...')
# Out:
# ...
# <ipython-input-166-2cdfa835c31a>:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   santander[columna] = santander[columna].str.replace('(','')
# <ipython-input-166-2cdfa835c31a>:6: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   santander[columna] = santander[columna].str.replace(')','')

# %%
santander[trimestre+'_SANTANDER'] = santander.sum( axis = 1)
santander = santander[['CONCEPTO ',trimestre+'_SANTANDER']][1:].rename(columns = {'CONCEPTO ':'CONCEPTO_SANTANDER'})

# %%
santander
# Out:
#                                    CONCEPTO_SANTANDER  2T21_SANTANDER
# 2            MOVIMIENTOS INHERENTES ALOS ACCIONISTAS              0.0
# 3          Aplicación de resultados 2020 a resultado              0.0
# 4                           de ejercicios anteriores          40308.0
# 5                              Decreto de dividendos           6108.0
# 6                                              TOTAL          40308.0
# 7   MOVIMIENTOS INHERENTES AL RECONOCIMIENTO DE LA...             0.0
# 8                 Resultado por valuación de títulos              0.0
# 9                             disponibles para venta          10436.0
# 10  Resultados por valuación de instrumentos de co...          1020.0
# 11       Reconocimiento de pagos basados en acciones            216.0
# 12                             Acciones en tesorería             14.0
# 13  Intereses sobre obligaciones subordinadas perp...             0.0
# 14                                           capital            618.0
# 15  Remediciones por beneficios definidos a los em...           166.0
# 16  Resultado por venta negocio adquiriente Result...      11217104.0
# 17                     Participación no controladora             22.0
# 18                                             TOTAL          18850.0
# 19                     SALDOS AL 30 DE JUNIO DE 2021         326266.0

# %%
final = pd.DataFrame()
finals = []

result = checker2(bbva.CONCEPTO_BBVA, banorte.CONCEPTO_BANORTE)


finals.append(result)
final = pd.concat(finals)

final_2 = pd.DataFrame()
finals_2 = []

result_2 = checker3(bbva.CONCEPTO_BBVA, santander.CONCEPTO_SANTANDER)


finals_2.append(result_2)
final_2 = pd.concat(finals_2)

# %%
conceptos = final[final.Score2>60]
bbva_2 = bbva.merge(conceptos[['CONCEPTO_BBVA','CONCEPTO_BANORTE']],how = 'left')
balance = bbva_2.merge(banorte , how = 'left')
balance  = balance.drop_duplicates()

# %%
conceptos2 = final_2[final_2.Score2>60]
balance_2 = balance.merge(conceptos2[['CONCEPTO_BBVA','CONCEPTO_SANTANDER']],how = 'left')
balance_2 = balance_2.merge(santander , how = 'left')
balance_2  = balance_2.drop_duplicates()

# %%
balance_2
# Out:
#                                         CONCEPTO_BBVA  2T21_BBVA  \
# 0                  Saldos al 31 de Diciembre de 2020    271564.0
# 1   MOVIMIENTOS INHERENTES A LAS DECISIONES DELOS ...        NaN
# 2   Traspaso del resultado neto a resultado de eje...        0.0
# 3                              Decreto de dividendos     11080.0
# 4   Capitalización de resultados de ejercicios ant...        NaN
# 5                                              Total     11080.0
# 6                                              Total     11080.0
# 9                                              Total     11080.0
# 10                                             Total     11080.0
# 13  MOVIMIENTOS INHERENTES AL RECONOCIMIENTO DE LA...        NaN
# 14                                    Resultado neto     25900.0
# 15  Resultado por valaluación de títulos disponibl...     6431.0
# 16  Resultado por valuación de instrumentos de cob...      466.0
# 17                   Efecto acumulado por conversión       440.0
# 18  Remediciones por beneficios definidos a los em...     3557.0
# 19                                             Total     22120.0
# 20                                             Total     22120.0
# 23                                             Total     22120.0
# 24                                             Total     22120.0
# 27                      Saldo al 30 de Junio de 2021    282604.0
#
#                                      CONCEPTO_BANORTE  2T21_BANORTE  \
# 0                  Saldos al 31 de Diciembre de 2020       276570.0
# 1   Movimientos inherentes al reconocimiento de la...           0.0
# 2                                                 NaN           NaN
# 3                                                 NaN           NaN
# 4                                                 NaN           NaN
# 5                                              Total        41724.0
# 6                                              Total        41724.0
# 9                                              Total        25110.0
# 10                                             Total        25110.0
# 13  Movimientos inherentes al reconocimiento de la...           0.0
# 14                                    Resultado neto        24990.0
# 15  Resultado por Valuación de títulos disponibles...        2410.0
# 16  Resultado por Valuación de Instrumentos de cob...        3182.0
# 17                   Efecto acumulado por conversión            4.0
# 18  Remediciones por beneficios definidos a los em...         120.0
# 19                                             Total        41724.0
# 20                                             Total        41724.0
# 23                                             Total        25110.0
# 24                                             Total        25110.0
# 27                     Saldos al 30 de Junio de 2021       296370.0
#
#                                    CONCEPTO_SANTANDER  2T21_SANTANDER
# 0                      SALDOS AL 30 DE JUNIO DE 2021         326266.0
# 1            MOVIMIENTOS INHERENTES ALOS ACCIONISTAS              0.0
# 2   Resultado por venta negocio adquiriente Result...      11217104.0
# 3                              Decreto de dividendos           6108.0
# 4                                                 NaN             NaN
# 5                                              TOTAL          40308.0
# 6                                              TOTAL          18850.0
# 9                                              TOTAL          40308.0
# 10                                             TOTAL          18850.0
# 13  MOVIMIENTOS INHERENTES AL RECONOCIMIENTO DE LA...             0.0
# 14                                                NaN             NaN
# 15                Resultado por valuación de títulos              0.0
# 16  Resultados por valuación de instrumentos de co...          1020.0
# 17                                                NaN             NaN
# 18  Remediciones por beneficios definidos a los em...           166.0
# 19                                             TOTAL          40308.0
# 20                                             TOTAL          18850.0
# 23                                             TOTAL          40308.0
# 24                                             TOTAL          18850.0
# 27                     SALDOS AL 30 DE JUNIO DE 2021         326266.0

# %%
for columna in balance_2.drop(columns = ['CONCEPTO_BBVA','CONCEPTO_BANORTE','CONCEPTO_SANTANDER']).columns:
    try: 
        balance_2[columna] = balance_2[columna].str.replace(',','')
        balance_2[columna] = balance_2[columna].str.replace(' ','')
        balance_2[columna] = balance_2[columna].str.replace('(','')
        balance_2[columna] = balance_2[columna].str.replace(')','')
        balance_2[columna] = balance_2[columna].str.replace('-','')
        balance_2[columna] = balance_2[columna].str.extract('(\d+)').astype(float)
    except:
        print('...')
# Out:
# ...
# ...
# ...

# %%
balance_2
# Out:
#                                         CONCEPTO_BBVA  2T21_BBVA  \
# 0                  Saldos al 31 de Diciembre de 2020    271564.0
# 1   MOVIMIENTOS INHERENTES A LAS DECISIONES DELOS ...        NaN
# 2   Traspaso del resultado neto a resultado de eje...        0.0
# 3                              Decreto de dividendos     11080.0
# 4   Capitalización de resultados de ejercicios ant...        NaN
# 5                                              Total     11080.0
# 6                                              Total     11080.0
# 9                                              Total     11080.0
# 10                                             Total     11080.0
# 13  MOVIMIENTOS INHERENTES AL RECONOCIMIENTO DE LA...        NaN
# 14                                    Resultado neto     25900.0
# 15  Resultado por valaluación de títulos disponibl...     6431.0
# 16  Resultado por valuación de instrumentos de cob...      466.0
# 17                   Efecto acumulado por conversión       440.0
# 18  Remediciones por beneficios definidos a los em...     3557.0
# 19                                             Total     22120.0
# 20                                             Total     22120.0
# 23                                             Total     22120.0
# 24                                             Total     22120.0
# 27                      Saldo al 30 de Junio de 2021    282604.0
#
#                                      CONCEPTO_BANORTE  2T21_BANORTE  \
# 0                  Saldos al 31 de Diciembre de 2020       276570.0
# 1   Movimientos inherentes al reconocimiento de la...           0.0
# 2                                                 NaN           NaN
# 3                                                 NaN           NaN
# 4                                                 NaN           NaN
# 5                                              Total        41724.0
# 6                                              Total        41724.0
# 9                                              Total        25110.0
# 10                                             Total        25110.0
# 13  Movimientos inherentes al reconocimiento de la...           0.0
# 14                                    Resultado neto        24990.0
# 15  Resultado por Valuación de títulos disponibles...        2410.0
# 16  Resultado por Valuación de Instrumentos de cob...        3182.0
# 17                   Efecto acumulado por conversión            4.0
# 18  Remediciones por beneficios definidos a los em...         120.0
# 19                                             Total        41724.0
# 20                                             Total        41724.0
# 23                                             Total        25110.0
# 24                                             Total        25110.0
# 27                     Saldos al 30 de Junio de 2021       296370.0
#
#                                    CONCEPTO_SANTANDER  2T21_SANTANDER
# 0                      SALDOS AL 30 DE JUNIO DE 2021         326266.0
# 1            MOVIMIENTOS INHERENTES ALOS ACCIONISTAS              0.0
# 2   Resultado por venta negocio adquiriente Result...      11217104.0
# 3                              Decreto de dividendos           6108.0
# 4                                                 NaN             NaN
# 5                                              TOTAL          40308.0
# 6                                              TOTAL          18850.0
# 9                                              TOTAL          40308.0
# 10                                             TOTAL          18850.0
# 13  MOVIMIENTOS INHERENTES AL RECONOCIMIENTO DE LA...             0.0
# 14                                                NaN             NaN
# 15                Resultado por valuación de títulos              0.0
# 16  Resultados por valuación de instrumentos de co...          1020.0
# 17                                                NaN             NaN
# 18  Remediciones por beneficios definidos a los em...           166.0
# 19                                             TOTAL          40308.0
# 20                                             TOTAL          18850.0
# 23                                             TOTAL          40308.0
# 24                                             TOTAL          18850.0
# 27                     SALDOS AL 30 DE JUNIO DE 2021         326266.0

# %%
balance_2.to_csv('C:/Users/josed/Downloads/Estado_de_variaciones/Estado_de_variaciones_'+trimestre+'.csv')

# %%
b1 = pd.read_csv('C:/Users/josed/Downloads/Estado_de_variaciones/Estado_de_variaciones_2T20.csv').drop(columns = 'Unnamed: 0')
b2 = pd.read_csv('C:/Users/josed/Downloads/Estado_de_variaciones/Estado_de_variaciones_3T20.csv').drop(columns = 'Unnamed: 0')
b3 = pd.read_csv('C:/Users/josed/Downloads/Estado_de_variaciones/Estado_de_variaciones_4T20.csv').drop(columns = 'Unnamed: 0')
b4 = pd.read_csv('C:/Users/josed/Downloads/Estado_de_variaciones/Estado_de_variaciones_1T21.csv').drop(columns = 'Unnamed: 0')
b5 = pd.read_csv('C:/Users/josed/Downloads/Estado_de_variaciones/Estado_de_variaciones_2T21.csv').drop(columns = 'Unnamed: 0')
b1 = b1.merge(b2[list(set(b2.columns )- set (b1.columns))+['CONCEPTO_BBVA']],how = 'left')
b1 = b1.merge(b3[list(set(b3.columns )- set (b1.columns))+['CONCEPTO_BBVA']],how = 'left')
b1 = b1.merge(b4[list(set(b4.columns )- set (b1.columns))+['CONCEPTO_BBVA']],how = 'left')
b1 = b1.merge(b5[list(set(b5.columns )- set (b1.columns))+['CONCEPTO_BBVA']],how = 'left')

# %%
b1.to_csv('Estado_de_variaciones_join_completo.csv')

# %%
b1 = b1.groupby(['CONCEPTO_BBVA']).head(1)
