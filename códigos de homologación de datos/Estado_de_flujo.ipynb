# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import os

# %%
import pandas as pd
from fuzzywuzzy import fuzz 
from fuzzywuzzy import process
import os, glob
import time

import nltk
import numpy as np
import re
from nltk.tokenize import word_tokenize
from nltk.stem import SnowballStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
# Out:
# C:\Users\josed\anaconda3\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
def checker2(wrong_options, correct_options):
    i=0
    results = [] 
    for wrong_option in wrong_options:
#        print(wrong_option)
        
#        buenas = wrong_options[wrong_options.Nombre == wrong_option]['Nielsen'].unique()
#        print(buenas)
#        correct_options = correct_options_2[correct_options_2.Desc_Categ.isin(buenas) ]['texto_limpio']
#        print(correct_options)
        
        x = process.extract(wrong_option, correct_options, scorer=fuzz.token_sort_ratio, limit = 1)
#        print(x)
        x = pd.DataFrame(x, columns = ['CONCEPTO_BANORTE','Score2','Familia'])

        #y = process.extract(wrong_option, correct_options, scorer=fuzz.partial_ratio, limit = 6)
        #y = pd.DataFrame(y, columns = ['Similares3','Score3'])

        #x = pd.concat([x, y], axis = 1)
        x = pd.concat([x], axis = 1)

        x['CONCEPTO_BBVA'] = wrong_option
 #       x['tabla_banorte'] = tabla_banorte
 #       x['tabla_santander'] = tabla_santander
        
        results.append(x)
        i+=1
#        print(i)   
    result = pd.concat( results , sort = False)
#    result['articulo_asociado'] = tipo
    return result

# %%
def checker3(wrong_options, correct_options):
    i=0
    results = [] 
    for wrong_option in wrong_options:
#        print(wrong_option)
        
#        buenas = wrong_options[wrong_options.Nombre == wrong_option]['Nielsen'].unique()
#        print(buenas)
#        correct_options = correct_options_2[correct_options_2.Desc_Categ.isin(buenas) ]['texto_limpio']
#        print(correct_options)
        
        x = process.extract(wrong_option, correct_options, scorer=fuzz.token_sort_ratio, limit = 1)
#        print(x)
        x = pd.DataFrame(x, columns = ['CONCEPTO_SANTANDER','Score2','Familia'])

        #y = process.extract(wrong_option, correct_options, scorer=fuzz.partial_ratio, limit = 6)
        #y = pd.DataFrame(y, columns = ['Similares3','Score3'])

        #x = pd.concat([x, y], axis = 1)
        x = pd.concat([x], axis = 1)

        x['CONCEPTO_BBVA'] = wrong_option
 #       x['tabla_banorte'] = tabla_banorte
 #       x['tabla_santander'] = tabla_santander
        
        results.append(x)
        i+=1
#        print(i)   
    result = pd.concat( results , sort = False)
#    result['articulo_asociado'] = tipo
    return result

# %%
trimestres = ['1T21','2T21','2T20','3T20','4T20']

# %%
trimestre = '2T21'
reporte = 'Estado_de_flujo'

# %%
int(trimestre[-2:])
# Out:
# 21

# %%
lista_bbva = (os.listdir('C:/Users/josed/Downloads/OUTPUT_BBVA_2021_3/Output/BBVA_'+reporte+'_'+trimestre))      
tablas_bbva = [s for s in lista_bbva if "table" in s]
bbva = pd.DataFrame()
for i in tablas_bbva:
#        print(i)
    globals()[f'bbva_'+ i[-5]] = pd.read_csv('C:/Users/josed/Downloads/OUTPUT_BBVA_2021_3/Output/BBVA_'+reporte+'_'+trimestre+'/'+i)
    globals()[f'bbva_'+ i[-5]].columns = globals()[f'bbva_'+ i[-5]].columns.str.replace(' 20','')
    globals()[f'bbva_'+ i[-5]] = globals()[f'bbva_'+ i[-5]].rename(columns = {globals()[f'bbva_'+ i[-5]].columns[0] : 'CONCEPTO'})
    bbva = pd.concat([bbva,globals()[f'bbva_'+ i[-5]]],axis = 0)


vec_c = []
for columna in bbva.columns:
    nueva_columna = str(columna)+'_BBVA'
    vec_c.append(nueva_columna)
bbva.columns = vec_c 
    
banorte = pd.DataFrame()    
lista_banorte = (os.listdir('C:/Users/josed/Downloads/OUTPUT_BBVA_2021_3/Output/Banorte_'+reporte+'_'+trimestre))      
tablas_banorte = [s for s in lista_banorte if "table" in s]
for i in tablas_banorte:
#        print(i)
    globals()[f'banorte_'+ i[-5]] = pd.read_csv('C:/Users/josed/Downloads/OUTPUT_BBVA_2021_3/Output/Banorte_'+reporte+'_'+trimestre+'/'+i)
    globals()[f'banorte_'+ i[-5]].columns = globals()[f'banorte_'+ i[-5]].columns.str.replace('1T','Mar')
    globals()[f'banorte_'+ i[-5]].columns = globals()[f'banorte_'+ i[-5]].columns.str.replace('2T','Jun')
    globals()[f'banorte_'+ i[-5]].columns = globals()[f'banorte_'+ i[-5]].columns.str.replace('3T','Sep')
    globals()[f'banorte_'+ i[-5]].columns = globals()[f'banorte_'+ i[-5]].columns.str.replace('4T','Dic')
    globals()[f'banorte_'+ i[-5]] = globals()[f'banorte_'+ i[-5]].rename(columns = {globals()[f'banorte_'+ i[-5]].columns[0] : 'CONCEPTO'})

    banorte = pd.concat([banorte,globals()[f'banorte_'+ i[-5]]],axis = 0)
   
vec_c = []
for columna in banorte.columns:
    nueva_columna = str(columna)+'_BANORTE'
    vec_c.append(nueva_columna)
banorte.columns = vec_c

santander = pd.DataFrame()   
lista_santander = (os.listdir('C:/Users/josed/Downloads/OUTPUT_BBVA_2021_3/Output/Santander_'+reporte+'_'+trimestre))      
tablas_santander = [s for s in lista_santander if "table" in s]
anio = int(trimestre[-2:])
for i in tablas_santander:
    globals()[f'santander_'+ i[-5]] = pd.read_csv('C:/Users/josed/Downloads/OUTPUT_BBVA_2021_3/Output/Santander_'+reporte+'_'+trimestre+'/'+i)
    if any("Mar" in s for s in globals()[f'santander_'+ i[-5]].columns):
        print('chido') 
    else:
        globals()[f'santander_'+ i[-5]].columns =globals()[f'santander_'+ i[-5]].values[0]
        
    vec = []
    for columna in globals()[f'santander_1'].values[0]:
        nueva_columna = str(columna)+str(anio)
        if 'Mar '+str(anio) in vec:
            nueva_columna = str(columna)+str(anio-1)
        vec.append(nueva_columna)
        
    globals()[f'santander_'+ i[-5]].columns = vec
    globals()[f'santander_'+ i[-5]].columns = globals()[f'santander_'+ i[-5]].columns.str.replace(' ','')
    globals()[f'santander_'+ i[-5]] = globals()[f'santander_'+ i[-5]].rename(columns = {globals()[f'santander_'+ i[-5]].columns[0] : 'CONCEPTO'})
    santander = pd.concat([santander,globals()[f'santander_'+ i[-5]]],axis = 0)    
    
vec_c = []
for columna in santander.columns[:-1]:
    nueva_columna = str(columna)+'_SANTANDER'
    vec_c.append(nueva_columna)
ultima = 'nada_2'
vec_c.append(ultima)
santander.columns = vec_c

# %%
bbva[bbva.columns[1]] = bbva[bbva.columns[1]].str.replace(',','')
bbva[bbva.columns[1]] = bbva[bbva.columns[1]].str.replace(' ','')
bbva[bbva.columns[1]] = bbva[bbva.columns[1]].str.replace('(','')
bbva[bbva.columns[1]] = bbva[bbva.columns[1]].str.replace(')','')
bbva[bbva.columns[1]] = bbva[bbva.columns[1]].str.replace('-','')
bbva[bbva.columns[1]] = bbva[bbva.columns[1]].str.extract('(\d+)').astype(float)
# Out:
# <ipython-input-209-e0b712532d5f>:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   bbva[bbva.columns[1]] = bbva[bbva.columns[1]].str.replace('(','')
# <ipython-input-209-e0b712532d5f>:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   bbva[bbva.columns[1]] = bbva[bbva.columns[1]].str.replace(')','')

# %%
banorte[banorte.columns[1]] = banorte[banorte.columns[1]].str.replace(',','')
banorte[banorte.columns[1]] = banorte[banorte.columns[1]].str.replace(' ','')
banorte[banorte.columns[1]] = banorte[banorte.columns[1]].str.replace('(','')
banorte[banorte.columns[1]] = banorte[banorte.columns[1]].str.replace(')','')
banorte[banorte.columns[1]] = banorte[banorte.columns[1]].str.replace('-','')
# Out:
# <ipython-input-210-39c19e279b8c>:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   banorte[banorte.columns[1]] = banorte[banorte.columns[1]].str.replace('(','')
# <ipython-input-210-39c19e279b8c>:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   banorte[banorte.columns[1]] = banorte[banorte.columns[1]].str.replace(')','')

# %%
bbva = bbva.rename(columns={bbva.columns[1]:'BBVA_'+trimestre})

# %%
bbva = bbva[['CONCEPTO_BBVA','BBVA_'+trimestre]]

# %%
banorte = banorte.rename(columns={banorte.columns[1]:'BANORTE_'+trimestre})

# %%
banorte = banorte[['CONCEPTO_BANORTE','BANORTE_'+trimestre]]

# %%
santander
# Out:
#                                    CONCEPTO_SANTANDER nan21_SANTANDER  \
# 0                                  Millones de pesos              NaN
# 1                           ACTIVIDADES DE OPERACIÓN              NaN
# 2                                     Resultado neto              NaN
# 3   Ajuste por partidas que no implican flujo de e...             NaN
# 4   Resultado por valorización asociada a activida...            458
# 5         Participación en el resultado de asociadas           (127)
# 6   Depreciaciones de inmuebles, mobiliario y equipo           1,048
# 7              Amortizaciones de activos intangibles           1,296
# 8        Reconocimiento de pagos basados en acciones             108
# 9       Impuestos a la utilidad causados y diferidos           2,282
# 10  Participación de los trabajadores en las utili...              9
# 11                                       Provisiones             169
# 12      Amortizaciones de gastos de emisión de deuda               9
# 13                          ACTIVIDADES DE OPERACIÓN              NaN
# 14                                 Cuentas de margen              NaN
# 15                            Inversiones en valores              NaN
# 16                              Deudores por reporto              NaN
# 17                                Derivados (activo)              NaN
# 18                         Cartera de crédito (neto)              NaN
# 19  Beneficios a recibir en operaciones de bursati...             NaN
# 20                                Bienes adjudicados              NaN
# 21                          Otros activos operativos              NaN
# 22                                         Captación              NaN
# 23         Préstamos bancarios y de otros organismos              NaN
# 24                            Acreedores por reporto              NaN
# 25          Colaterales vendidos o dados en garantía              NaN
# 26                                Derivados (pasivo)              NaN
# 27                          Otros pasivos operativos              NaN
# 28                  Pagos de impuestos a la utilidad              NaN
# 29  Flujos netos de efectivo de actividades de ope...             NaN
# 30                          ACTIVIDADES DE INVERSIÓN              NaN
# 31  Cobros por disposición de inmuebles, mobiliari...             NaN
# 32  Pagos por adquisición de inmuebles, mobiliario...             NaN
# 33  Cobro por devolución de indemnityde entidad as...             NaN
# 34      Pagos por adquisición de activos intangibles              NaN
# 35  Flujos netos de efectivo de actividades de inv...             NaN
# 36                     ACTIVIDADES DE FINANCIAMIENTO              NaN
# 37                    Pago de dividendos en efectivo              NaN
# 38  Pago de intereses sobre obligaciones subordina...             NaN
# 39            susceptibles de convertirse en capital              NaN
# 40  Pagos asociados a la recompra de acciones prop...             NaN
# 41  Flujos netos de efectivo de actividades de fin...             NaN
# 42  Decremento neto de efectivo y equivalentes de ...             NaN
# 43  Efectos por cambios en el valor del efectivo y...             NaN
# 44  Efectivo y equivalentes de efectivo al inicio ...             NaN
# 45  Efectivo y equivalentes de efectivo al final d...             NaN
#
#    nan21_SANTANDER  nada_2
# 0              NaN     NaN
# 1              NaN     NaN
# 2           7,992      NaN
# 3              NaN     NaN
# 4              NaN     NaN
# 5              NaN     NaN
# 6              NaN     NaN
# 7              NaN     NaN
# 8              NaN     NaN
# 9              NaN     NaN
# 10             NaN     NaN
# 11             NaN     NaN
# 12          5,252      NaN
# 13         13,244      NaN
# 14        (1,086)      NaN
# 15        110,793      NaN
# 16         22,788      NaN
# 17        104,737      NaN
# 18        (8,720)      NaN
# 19            160      NaN
# 20             29      NaN
# 21          8,647      NaN
# 22        (4,266)      NaN
# 23        (4,555)      NaN
# 24      (159,991)      NaN
# 25         14,146      NaN
# 26      (108,703)      NaN
# 27         39,663      NaN
# 28        (2,589)      NaN
# 29         11,053      NaN
# 30             NaN     NaN
# 31              2      NaN
# 32          (541)      NaN
# 33             54      NaN
# 34          (964)      NaN
# 35        (1,449)      NaN
# 36             NaN     NaN
# 37        (3,054)      NaN
# 38          (309)      NaN
# 39             NaN     NaN
# 40            (7)      NaN
# 41        (3,370)      NaN
# 42         19,478      NaN
# 43          (437)      NaN
# 44         94,802      NaN
# 45        113,843      NaN

# %%
santander = santander[santander.columns[:2]]

# %%
santander.columns = ['CONCEPTO_SANTANDER', 'nada_1', 'nada_2','nada_3']

# %%
santander
# Out:
#                                    CONCEPTO_SANTANDER  nada_1      nada_2  \
# 0                                  Millones de pesos      NaN         NaN
# 1                           ACTIVIDADES DE OPERACIÓN      NaN         NaN
# 2                                     Resultado neto      NaN      7,992
# 3   Ajuste por partidas que no implican flujo de e...     NaN         NaN
# 4   Resultado por valorización asociada a activida...    458          NaN
# 5         Participación en el resultado de asociadas   (127)          NaN
# 6   Depreciaciones de inmuebles, mobiliario y equipo   1,048          NaN
# 7              Amortizaciones de activos intangibles   1,296          NaN
# 8        Reconocimiento de pagos basados en acciones     108          NaN
# 9       Impuestos a la utilidad causados y diferidos   2,282          NaN
# 10  Participación de los trabajadores en las utili...      9          NaN
# 11                                       Provisiones     169          NaN
# 12      Amortizaciones de gastos de emisión de deuda       9       5,252
# 13                          ACTIVIDADES DE OPERACIÓN      NaN     13,244
# 14                                 Cuentas de margen      NaN    (1,086)
# 15                            Inversiones en valores      NaN    110,793
# 16                              Deudores por reporto      NaN     22,788
# 17                                Derivados (activo)      NaN    104,737
# 18                         Cartera de crédito (neto)      NaN    (8,720)
# 19  Beneficios a recibir en operaciones de bursati...     NaN        160
# 20                                Bienes adjudicados      NaN         29
# 21                          Otros activos operativos      NaN      8,647
# 22                                         Captación      NaN    (4,266)
# 23         Préstamos bancarios y de otros organismos      NaN    (4,555)
# 24                            Acreedores por reporto      NaN  (159,991)
# 25          Colaterales vendidos o dados en garantía      NaN     14,146
# 26                                Derivados (pasivo)      NaN  (108,703)
# 27                          Otros pasivos operativos      NaN     39,663
# 28                  Pagos de impuestos a la utilidad      NaN    (2,589)
# 29  Flujos netos de efectivo de actividades de ope...     NaN     11,053
# 30                          ACTIVIDADES DE INVERSIÓN      NaN         NaN
# 31  Cobros por disposición de inmuebles, mobiliari...     NaN          2
# 32  Pagos por adquisición de inmuebles, mobiliario...     NaN      (541)
# 33  Cobro por devolución de indemnityde entidad as...     NaN         54
# 34      Pagos por adquisición de activos intangibles      NaN      (964)
# 35  Flujos netos de efectivo de actividades de inv...     NaN    (1,449)
# 36                     ACTIVIDADES DE FINANCIAMIENTO      NaN         NaN
# 37                    Pago de dividendos en efectivo      NaN    (3,054)
# 38  Pago de intereses sobre obligaciones subordina...     NaN      (309)
# 39            susceptibles de convertirse en capital      NaN         NaN
# 40  Pagos asociados a la recompra de acciones prop...     NaN        (7)
# 41  Flujos netos de efectivo de actividades de fin...     NaN    (3,370)
# 42  Decremento neto de efectivo y equivalentes de ...     NaN     19,478
# 43  Efectos por cambios en el valor del efectivo y...     NaN      (437)
# 44  Efectivo y equivalentes de efectivo al inicio ...     NaN     94,802
# 45  Efectivo y equivalentes de efectivo al final d...     NaN    113,843
#
#     nada_3
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
# 6      NaN
# 7      NaN
# 8      NaN
# 9      NaN
# 10     NaN
# 11     NaN
# 12     NaN
# 13     NaN
# 14     NaN
# 15     NaN
# 16     NaN
# 17     NaN
# 18     NaN
# 19     NaN
# 20     NaN
# 21     NaN
# 22     NaN
# 23     NaN
# 24     NaN
# 25     NaN
# 26     NaN
# 27     NaN
# 28     NaN
# 29     NaN
# 30     NaN
# 31     NaN
# 32     NaN
# 33     NaN
# 34     NaN
# 35     NaN
# 36     NaN
# 37     NaN
# 38     NaN
# 39     NaN
# 40     NaN
# 41     NaN
# 42     NaN
# 43     NaN
# 44     NaN
# 45     NaN

# %%
santander[santander.columns[1]] = santander[santander.columns[1]].str.replace(',','')
santander[santander.columns[1]] = santander[santander.columns[1]].str.replace(' ','')
santander[santander.columns[1]] = santander[santander.columns[1]].str.replace('(','')
santander[santander.columns[1]] = santander[santander.columns[1]].str.replace(')','')
santander[santander.columns[1]] = santander[santander.columns[1]].str.replace('-','')
santander[santander.columns[1]] = santander[santander.columns[1]].str.extract('(\d+)').astype(float)

santander[santander.columns[2]] = santander[santander.columns[2]].str.replace(',','')
santander[santander.columns[2]] = santander[santander.columns[2]].str.replace(' ','')
santander[santander.columns[2]] = santander[santander.columns[2]].str.replace('(','')
santander[santander.columns[2]] = santander[santander.columns[2]].str.replace(')','')
santander[santander.columns[2]] = santander[santander.columns[2]].str.replace('-','')
santander[santander.columns[2]] = santander[santander.columns[2]].str.extract('(\d+)').astype(float)
# Out:
# <ipython-input-218-922e50e5b903>:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   santander[santander.columns[1]] = santander[santander.columns[1]].str.replace('(','')
# <ipython-input-218-922e50e5b903>:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   santander[santander.columns[1]] = santander[santander.columns[1]].str.replace(')','')
# <ipython-input-218-922e50e5b903>:10: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   santander[santander.columns[2]] = santander[santander.columns[2]].str.replace('(','')
# <ipython-input-218-922e50e5b903>:11: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   santander[santander.columns[2]] = santander[santander.columns[2]].str.replace(')','')

# %%
santander['SANTANDER_'+trimestre] = santander.sum(axis = 1)

# %%
santander = santander[['CONCEPTO_SANTANDER','SANTANDER_'+trimestre]]

# %%
santander
# Out:
#                                    CONCEPTO_SANTANDER  SANTANDER_2T21
# 0                                  Millones de pesos              0.0
# 1                           ACTIVIDADES DE OPERACIÓN              0.0
# 2                                     Resultado neto           7992.0
# 3   Ajuste por partidas que no implican flujo de e...             0.0
# 4   Resultado por valorización asociada a activida...           458.0
# 5         Participación en el resultado de asociadas            127.0
# 6   Depreciaciones de inmuebles, mobiliario y equipo           1048.0
# 7              Amortizaciones de activos intangibles           1296.0
# 8        Reconocimiento de pagos basados en acciones            108.0
# 9       Impuestos a la utilidad causados y diferidos           2282.0
# 10  Participación de los trabajadores en las utili...             9.0
# 11                                       Provisiones            169.0
# 12      Amortizaciones de gastos de emisión de deuda           5261.0
# 13                          ACTIVIDADES DE OPERACIÓN          13244.0
# 14                                 Cuentas de margen           1086.0
# 15                            Inversiones en valores         110793.0
# 16                              Deudores por reporto          22788.0
# 17                                Derivados (activo)         104737.0
# 18                         Cartera de crédito (neto)           8720.0
# 19  Beneficios a recibir en operaciones de bursati...           160.0
# 20                                Bienes adjudicados             29.0
# 21                          Otros activos operativos           8647.0
# 22                                         Captación           4266.0
# 23         Préstamos bancarios y de otros organismos           4555.0
# 24                            Acreedores por reporto         159991.0
# 25          Colaterales vendidos o dados en garantía          14146.0
# 26                                Derivados (pasivo)         108703.0
# 27                          Otros pasivos operativos          39663.0
# 28                  Pagos de impuestos a la utilidad           2589.0
# 29  Flujos netos de efectivo de actividades de ope...         11053.0
# 30                          ACTIVIDADES DE INVERSIÓN              0.0
# 31  Cobros por disposición de inmuebles, mobiliari...             2.0
# 32  Pagos por adquisición de inmuebles, mobiliario...           541.0
# 33  Cobro por devolución de indemnityde entidad as...            54.0
# 34      Pagos por adquisición de activos intangibles            964.0
# 35  Flujos netos de efectivo de actividades de inv...          1449.0
# 36                     ACTIVIDADES DE FINANCIAMIENTO              0.0
# 37                    Pago de dividendos en efectivo           3054.0
# 38  Pago de intereses sobre obligaciones subordina...           309.0
# 39            susceptibles de convertirse en capital              0.0
# 40  Pagos asociados a la recompra de acciones prop...             7.0
# 41  Flujos netos de efectivo de actividades de fin...          3370.0
# 42  Decremento neto de efectivo y equivalentes de ...         19478.0
# 43  Efectos por cambios en el valor del efectivo y...           437.0
# 44  Efectivo y equivalentes de efectivo al inicio ...         94802.0
# 45  Efectivo y equivalentes de efectivo al final d...        113843.0

# %%
final = pd.DataFrame()
finals = []

result = checker2(bbva.CONCEPTO_BBVA.dropna(), banorte.CONCEPTO_BANORTE.dropna())


finals.append(result)
final = pd.concat(finals)

final_2 = pd.DataFrame()
finals_2 = []

result_2 = checker3(bbva.CONCEPTO_BBVA.dropna(), santander.CONCEPTO_SANTANDER.dropna())


finals_2.append(result_2)
final_2 = pd.concat(finals_2)

# %%
conceptos = final[final.Score2>60]
bbva_2 = bbva.merge(conceptos[['CONCEPTO_BBVA','CONCEPTO_BANORTE']],how = 'left')
balance = bbva_2.merge(banorte , how = 'left')
balance  = balance.drop_duplicates()

# %%
conceptos2 = final_2[final_2.Score2>60]
balance_2 = balance.merge(conceptos2[['CONCEPTO_BBVA','CONCEPTO_SANTANDER']],how = 'left')
balance_2 = balance_2.merge(santander , how = 'left')
balance_2  = balance_2.drop_duplicates()

# %%
balance_2
# Out:
#                                         CONCEPTO_BBVA  BBVA_2T21  \
# 0   Depreciaciones de inmuebles, mobiliario ; y eq...        NaN
# 1        Amortizaciones de gastos de instalación 909         NaN
# 2        Amortizaciones de gastos de instalación 909         NaN
# 3          Amortizaciones de activos intangibles 900         NaN
# 4          Amortizaciones de activos intangibles 900         NaN
# 5                            Reservas técnicas 2,203         NaN
# 6                            Reservas técnicas 2,203         NaN
# 7                                  Provisiones 1,622         NaN
# 8   Reciclaje del efecto acumulado por conversión ...        NaN
# 9   Reciclaje del efecto acumulado por conversión ...        NaN
# 10  Impuestos ala utilidad causados y diferidos 11...        NaN
# 11  Participación en el resultado de subsidiarias ...        NaN
# 12                   Participación no controladora 5     17474.0
# 13                   Participación no controladora 5     17474.0
# 14                                                NaN    43369.0
# 15                                                NaN    43369.0
# 16                          Actividades de operación         NaN
# 17                          Actividades de operación         NaN
# 18                       Cambio en cuentas de margen     16978.0
# 19                  Cambio en inversiones en valores     43510.0
# 20                    Cambio en deudores por reporto     16160.0
# 21                      Cambio en derivados (activo)     64926.0
# 22               Cambio en cartera de crédito (neto)     22799.0
# 23              Cambio en deudores por primas (neto)      1534.0
# 24  Cambio en reaseguradores y reafianzadores (net...     2364.0
# 25               Cambio en bienes adjudicados (neto)       128.0
# 26         Cambio en otros activos operativos (neto)     41125.0
# 27                   Cambio en captación tradicional     36754.0
# 28  Cambio en préstamos interbancarios y de otros ...    12596.0
# 29                       Cambio en reservas técnicas     19415.0
# 30                       Cambio en reservas técnicas     19415.0
# 31                  Cambio en acreedores por reporto     44748.0
# 32            Cambio en préstamo de valores (pasivo)         5.0
# 33  Cambio en colaterales vendidos o dados en gara...    10774.0
# 34                      Cambio en derivados (pasivo)     64197.0
# 35  Cambio en reaseguradores y reafianzadores (net...      368.0
# 36  Cambio en reaseguradores y reafianzadores (net...      368.0
# 37  Cambio en obligaciones subordinadas con caract...    15230.0
# 38                Cambio en otros pasivos operativos     55543.0
# 39  Cambio en instrumentos de cobertura (de partid...     6132.0
# 40                  Pagos de impuestos a la utilidad      6236.0
# 41  Flujos netos de efectivo de actividades de ope...    53710.0
# 42                          Actividades de inversión         NaN
# 43  Cobros por disposición de inmuebles, mobiliari...       29.0
# 44  Pagos por adquisición de inmuebles, mobiliario...      975.0
# 45            Cobros por disposición de subsidiarias        93.0
# 46                  Cobros de dividendos en efectivo         1.0
# 47  Cobros por disposición de activos de larga dur...      107.0
# 48  Cobros por disposición de activos de larga dur...      107.0
# 49      Pagos por adquisición de activos intangibles       804.0
# 50  Flujos netos de efectivo de actividades de inv...     1549.0
# 51                     Actividades de financiamiento         NaN
# 52                   Pagos de dividendos en efectivo     11080.0
# 53  Flujos netos de efectivo de actividades de fin...    11080.0
# 54  Incremento o disminución neta de efectivo y eq...    84450.0
# 55  Efectos por cambios en el valor del efectivo y...       16.0
# 56  Efectivo y equivalentes de efectivo al inicio ...   223687.0
# 57  Efectivoy equivalentes de efectivo al final de...   308121.0
#
#                                      CONCEPTO_BANORTE BANORTE_2T21  \
# 0      Depreciación de Inmuebles, mobiliario yequipo          1172
# 1                                                 NaN         5185
# 2                                                 NaN        17680
# 3                                                 NaN         5185
# 4                                                 NaN        17680
# 5                                                 NaN         5185
# 6                                                 NaN        17680
# 7                                        Provisiones           273
# 8                                                 NaN         5185
# 9                                                 NaN        17680
# 10      Impuestos a la utilidad causados y diferidos          3981
# 11  Participación en el resultado de subsidiarias ...          241
# 12                                                NaN         5185
# 13                                                NaN        17680
# 14                                                NaN         5185
# 15                                                NaN        17680
# 16                          Actividades de operación           NaN
# 17                          Actividades de operación           NaN
# 18                       Cambio en cuentas de margen          9396
# 19                  Cambio en inversiones en valores           122
# 20                    Cambio en deudores por reporto           108
# 21                      Cambio en derivados (activo)         23894
# 22               Cambio en cartera de crédito (neto)          2654
# 23                    Cambio en deudores por reporto           108
# 24         Cambio en otros activos operativos (neto)          8734
# 25               Cambio en bienes adjudicados (neto)           428
# 26         Cambio en otros activos operativos (neto)          8734
# 27                   Cambio en captación tradicional         27864
# 28  Cambio en préstamos interbancarios y de otros ...           89
# 29                                                NaN         5185
# 30                                                NaN        17680
# 31                  Cambio en acreedores por reporto          3148
# 32                  Cambio en inversiones en valores           122
# 33  Cambio en colaterales vendidos o dados en gara...           42
# 34                      Cambio en derivados (pasivo)         24094
# 35                                                NaN         5185
# 36                                                NaN        17680
# 37  Cambio en obligaciones subordinadas con caract...           92
# 38                Cambio en otros pasivos operativos         13280
# 39  Cambio en instrumentos de cobertura (de partid...          438
# 40                   Pago de Impuestos a la utilidad          5317
# 41  Flujos netos de efectivo de actividades de ope...         4568
# 42                          Actividades de inversión           NaN
# 43  Cobros por disposición de inmuebles, mobiliari...          419
# 44  Pagos por adquisición de inmuebles, mobiliario...         1485
# 45  Cobros por disposición de inmuebles, mobiliari...          419
# 46                  Cobros de dividendos en efectivo            31
# 47                                                NaN         5185
# 48                                                NaN        17680
# 49  Pagos por adquisición de inmuebles, mobiliario...         1485
# 50  Flujos netos de efectivo de actividades de inv...         1044
# 51                     Actividades de financiamiento           NaN
# 52                  Cobros de dividendos en efectivo            31
# 53  Flujos netos de efectivo de actividades de fin...         1863
# 54  Incremento o disminución neta de efectivo y eq...         1661
# 55  Efectos por cambios en el valor del efectivo y...            3
# 56     Efectivo y equivalentes al inicio del período        108743
# 57      Efectivo y equivalentes al final del período        110407
#
#                                    CONCEPTO_SANTANDER  SANTANDER_2T21
# 0   Depreciaciones de inmuebles, mobiliario y equipo           1048.0
# 1       Amortizaciones de gastos de emisión de deuda           5261.0
# 2       Amortizaciones de gastos de emisión de deuda           5261.0
# 3              Amortizaciones de activos intangibles           1296.0
# 4              Amortizaciones de activos intangibles           1296.0
# 5                                                 NaN             NaN
# 6                                                 NaN             NaN
# 7                                        Provisiones            169.0
# 8                                                 NaN             NaN
# 9                                                 NaN             NaN
# 10      Impuestos a la utilidad causados y diferidos           2282.0
# 11        Participación en el resultado de asociadas            127.0
# 12                                                NaN             NaN
# 13                                                NaN             NaN
# 14                                                NaN             NaN
# 15                                                NaN             NaN
# 16                          ACTIVIDADES DE OPERACIÓN              0.0
# 17                          ACTIVIDADES DE OPERACIÓN          13244.0
# 18                                 Cuentas de margen           1086.0
# 19                            Inversiones en valores         110793.0
# 20                              Deudores por reporto          22788.0
# 21                                Derivados (activo)         104737.0
# 22                         Cartera de crédito (neto)           8720.0
# 23                                                NaN             NaN
# 24                                                NaN             NaN
# 25                                Bienes adjudicados             29.0
# 26                          Otros activos operativos           8647.0
# 27                                                NaN             NaN
# 28         Préstamos bancarios y de otros organismos           4555.0
# 29                                                NaN             NaN
# 30                                                NaN             NaN
# 31                            Acreedores por reporto         159991.0
# 32                                                NaN             NaN
# 33          Colaterales vendidos o dados en garantía          14146.0
# 34                                Derivados (pasivo)         108703.0
# 35                                                NaN             NaN
# 36                                                NaN             NaN
# 37                                                NaN             NaN
# 38                          Otros pasivos operativos          39663.0
# 39                                                NaN             NaN
# 40                  Pagos de impuestos a la utilidad           2589.0
# 41  Flujos netos de efectivo de actividades de ope...         11053.0
# 42                          ACTIVIDADES DE INVERSIÓN              0.0
# 43  Cobros por disposición de inmuebles, mobiliari...             2.0
# 44  Pagos por adquisición de inmuebles, mobiliario...           541.0
# 45                                                NaN             NaN
# 46                    Pago de dividendos en efectivo           3054.0
# 47                                                NaN             NaN
# 48                                                NaN             NaN
# 49      Pagos por adquisición de activos intangibles            964.0
# 50  Flujos netos de efectivo de actividades de inv...          1449.0
# 51                     ACTIVIDADES DE FINANCIAMIENTO              0.0
# 52                    Pago de dividendos en efectivo           3054.0
# 53  Flujos netos de efectivo de actividades de fin...          3370.0
# 54  Decremento neto de efectivo y equivalentes de ...         19478.0
# 55  Efectos por cambios en el valor del efectivo y...           437.0
# 56  Efectivo y equivalentes de efectivo al inicio ...         94802.0
# 57  Efectivo y equivalentes de efectivo al final d...        113843.0

# %%
balance_2.to_csv('C:/Users/josed/Downloads/Estado_de_flujo/Estado_de_flujo_'+trimestre+'.csv')

# %%
b1 = pd.read_csv('C:/Users/josed/Downloads/Estado_de_flujo/Estado_de_flujo_2T20.csv').drop(columns = 'Unnamed: 0')
b2 = pd.read_csv('C:/Users/josed/Downloads/Estado_de_flujo/Estado_de_flujo_3T20.csv').drop(columns = 'Unnamed: 0')
b3 = pd.read_csv('C:/Users/josed/Downloads/Estado_de_flujo/Estado_de_flujo_4T20.csv').drop(columns = 'Unnamed: 0')
b4 = pd.read_csv('C:/Users/josed/Downloads/Estado_de_flujo/Estado_de_flujo_1T21.csv').drop(columns = 'Unnamed: 0')
b5 = pd.read_csv('C:/Users/josed/Downloads/Estado_de_flujo/Estado_de_flujo_2T21.csv').drop(columns = 'Unnamed: 0')
b1 = b1.merge(b2[list(set(b2.columns )- set (b1.columns))+['CONCEPTO_BBVA']],how = 'left')
b1 = b1.merge(b3[list(set(b3.columns )- set (b1.columns))+['CONCEPTO_BBVA']],how = 'left')
b1 = b1.merge(b4[list(set(b4.columns )- set (b1.columns))+['CONCEPTO_BBVA']],how = 'left')
b1 = b1.merge(b5[list(set(b5.columns )- set (b1.columns))+['CONCEPTO_BBVA']],how = 'left')

# %%
b1.to_csv('Estado_de_flujo_join_completo.csv')
